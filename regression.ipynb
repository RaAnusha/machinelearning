# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('train.csv')
print(data)
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
data.set_index('POSTED_BY',inplace=True)
print(data)
# Out:
#            UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# POSTED_BY
# Owner                       0     0        2       BHK  1300.236407
# Dealer                      0     0        2       BHK  1275.000000
# Owner                       0     0        2       BHK   933.159722
# Owner                       0     1        2       BHK   929.921143
# Dealer                      1     0        2       BHK   999.009247
# ...                       ...   ...      ...       ...          ...
# Owner                       0     0        3       BHK  2500.000000
# Owner                       0     0        2       BHK   769.230769
# Dealer                      0     0        2       BHK  1022.641509
# Owner                       0     0        2       BHK   927.079009
# Dealer                      0     1        2       BHK   896.774194
#
#            READY_TO_MOVE  RESALE                            ADDRESS  \
# POSTED_BY
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (29451, 11)

# %%
data.isnull()
# Out:
#            UNDER_CONSTRUCTION   RERA  BHK_NO.  BHK_OR_RK  SQUARE_FT  \
# POSTED_BY
# Owner                   False  False    False      False      False
# Dealer                  False  False    False      False      False
# Owner                   False  False    False      False      False
# Owner                   False  False    False      False      False
# Dealer                  False  False    False      False      False
# ...                       ...    ...      ...        ...        ...
# Owner                   False  False    False      False      False
# Owner                   False  False    False      False      False
# Dealer                  False  False    False      False      False
# Owner                   False  False    False      False      False
# Dealer                  False  False    False      False      False
#
#            READY_TO_MOVE  RESALE  ADDRESS  LONGITUDE  LATITUDE  \
# POSTED_BY
# ...

# %%
data.columns
# Out:
# Index(['UNDER_CONSTRUCTION', 'RERA', 'BHK_NO.', 'BHK_OR_RK', 'SQUARE_FT',
#        'READY_TO_MOVE', 'RESALE', 'ADDRESS', 'LONGITUDE', 'LATITUDE',
#        'TARGET(PRICE_IN_LACS)'],
#       dtype='object')

# %%
data.head(10)
# Out:
#            UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# POSTED_BY
# Owner                       0     0        2       BHK  1300.236407
# Dealer                      0     0        2       BHK  1275.000000
# Owner                       0     0        2       BHK   933.159722
# Owner                       0     1        2       BHK   929.921143
# Dealer                      1     0        2       BHK   999.009247
# Owner                       0     0        3       BHK  1250.000000
# Dealer                      0     0        3       BHK  1495.053957
# Owner                       0     1        3       BHK  1181.012946
# Dealer                      0     1        2       BHK  1040.000000
# Owner                       0     1        2       BHK   879.120879
#
#            READY_TO_MOVE  RESALE                      ADDRESS  LONGITUDE  \
# POSTED_BY
# Owner                  1       1        Ksfc Layout,Bangalore  12.969910
# ...

# %%
data.tail()
# Out:
#            UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# POSTED_BY
# Owner                       0     0        3       BHK  2500.000000
# Owner                       0     0        2       BHK   769.230769
# Dealer                      0     0        2       BHK  1022.641509
# Owner                       0     0        2       BHK   927.079009
# Dealer                      0     1        2       BHK   896.774194
#
#            READY_TO_MOVE  RESALE                            ADDRESS  \
# POSTED_BY
# Owner                  1       1               Shamshabad Road,Agra
# Owner                  1       1  E3-108, Lake View Recidency,,Vapi
# Dealer                 1       1                  Ajmer Road,Jaipur
# Owner                  1       1             Sholinganallur,Chennai
# Dealer                 1       1                   Jagatpura,Jaipur
#
#            LONGITUDE   LATITUDE  TARGET(PRICE_IN_LACS)
# POSTED_BY
# Owner      27.140626  78.043277                   45.0
# ...

# %%
data.values
# Out:
# array([[0, 0, 2, ..., 12.96991, 77.59796, 55.0],
#        [0, 0, 2, ..., 12.274538, 76.644605, 51.0],
#        [0, 0, 2, ..., 12.778033, 77.632191, 43.0],
#        ...,
#        [0, 0, 2, ..., 26.928785, 75.828002, 27.1],
#        [0, 0, 2, ..., 12.90015, 80.22791, 67.0],
#        [0, 1, 2, ..., 26.832353, 75.841749, 27.8]], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29451 entries, Owner to Dealer
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   UNDER_CONSTRUCTION     29451 non-null  int64
#  1   RERA                   29451 non-null  int64
#  2   BHK_NO.                29451 non-null  int64
#  3   BHK_OR_RK              29451 non-null  object
#  4   SQUARE_FT              29451 non-null  float64
#  5   READY_TO_MOVE          29451 non-null  int64
#  6   RESALE                 29451 non-null  int64
#  7   ADDRESS                29451 non-null  object
#  8   LONGITUDE              29451 non-null  float64
#  9   LATITUDE               29451 non-null  float64
#  10  TARGET(PRICE_IN_LACS)  29451 non-null  float64
# dtypes: float64(4), int64(5), object(2)
# memory usage: 2.7+ MB
